# %% [markdown]
# # Import Amazon Music
# This workflow begins with raw Amazon product and product review data sourced from Kaggle at:
#
# https://www.kaggle.com/datasets/wajahat1064/amazon-reviews-data-2023
#
# As a prerequisite before running this workflow, download the Audio CD and Digital Music user reveiew and product metadata (4 datasets) from the above link and place them in the data/raw folder.

# %%
# %load_ext autoreload
# %autoreload 2

import json
import sqlite3 as sql

import pandas as pd

import sql_ingest as ingest
from jsonl_to_csv import jsonl_to_csv

# %run '../query/search.py'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### JSONL to CSV
# Large JSONL files are unwieldy to work with. Converting to CSV makes it feasible to import datasets in a single line of code within reasonable time span.

# %%
jsonl_to_csv('../raw/Digital_Music.jsonl', if_exists = 'skip')

# %%
jsonl_to_csv('../raw/meta_Digital_Music.jsonl', if_exists =  'skip')

# %%
jsonl_to_csv('../raw/CDs_and_Vinyl.jsonl', batch_size = 100_000, if_exists = 'skip')

# %%
jsonl_to_csv('../raw/meta_CDs_and_Vinyl.jsonl', batch_size = 100_000, if_exists = 'skip')

# %% [markdown]
# ## Normalize Format
#
# Next, let's combine digital music and CD data and convert the data format so that it matches our SQL backend.

# %%
# Amazon data from this dataset hides the album artist in a 'store' field containing artist and audio format.
# Let's extract only the artist from the store field:
def extract_artist(text: str) -> str:
    if type(text) != str:
        return text
    result = text.partition('Format:')[0]
    try:
        i = result.index('(')
        result = result[:i]
    except:
        pass
    return result.strip()

# Test
examples = [
    "Scandroid Format: Audio CD",
    "Scandroid (Artist) Format: Audio CD",
    "Beethoven (Composer), Berliner Philharmonika (Performer)",
]
for example in examples:
    artist = extract_artist(example)
    print(f"artist('{example}') = '{artist}'")

# Release dates are similarly hidden within a larger 'details' metadata field
def extract_release_date(details: str) -> str:
    details = details.replace("'", '"')
    try:
        meta = json.loads(details)
        return meta.get('Date First Available')
    except:
        return None

cases = [
    'Release Date',
    '{ "Artist": "Juno Reactor" }',
    "{ 'Date First Available': '2020-12-01' }",
    '{ "Date First Available": "2020-12-01" }'

]
for case in cases:
    date = extract_release_date(case)
    print(f'release date ({repr(case)}) = {repr(date)}')
# Out:
# artist('Scandroid Format: Audio CD') = 'Scandroid'
# artist('Scandroid (Artist) Format: Audio CD') = 'Scandroid'
# artist('Beethoven (Composer), Berliner Philharmonika (Performer)') = 'Beethoven'
# release date ('Release Date') = None
# release date ('{ "Artist": "Juno Reactor" }') = None
# release date ("{ 'Date First Available': '2020-12-01' }") = '2020-12-01'
# release date ('{ "Date First Available": "2020-12-01" }') = '2020-12-01'

# %%
def normalize_amazon_music_reviews(reviews: pd.DataFrame) -> pd.DataFrame:
    """
    Given an Amazon user review from Kaggle data, return a review in a normalized format compatible with our SQL backend.
    """
    # Review data schema:
    # - rating
    # - title
    # - text: user review text
    # - parent_asin: product id
    # - asin: redundant product id
    # - user_id
    # - helpful_vote: number of upvotes for this review
    # - timestamp
    # - images
    # - verified_purchase
    return reviews.rename(columns = {
        'text': 'review',
        'parent_asin': 'product_id',
        'helpful_vote': 'upvotes',
    }).drop(columns = ['asin', 'verified_purchase', 'images'])


def normalize_amazon_music_data(products: pd.DataFrame) -> pd.DataFrame:
    """
    Given an Amazon product description from Kaggle data, return a product description in a normalized format.
    """
    # Product data schema:
    # - main_category: music, books, etc
    # - title: album/product title
    # - average_rating: combined average user review rating
    # - rating_number: user review count
    # - features: miscellaneous notes for some rare/collectors CDs for example
    # - description: product description text
    # - price
    # - images
    # - store: contains combination of artist and audio format
    # - categories: ?
    # - details: dictionary with potentially large volumes of arbitrary metadata. Usually contains album release date. Catalog includes non-music items that can be identified by eccentric metadata if needed.
    # - parent_asin: product id
    # - bought_together: not used
    result = products.rename(columns = {
        'parent_asin': 'id',
        'main_category': 'category',
        'store': 'creator'
    }).drop(columns = [
        'average_rating', 'rating_number',
        'features',
        'price',
        'categories',
        'details',
        'bought_together',
        'subtitle',
        'author',
        'videos',
        'images'
    ])
    result['release_date'] = products.details.map(extract_release_date)
    # descriptions come in an array. but most products only have one. Let's join them into a single string.
    result.description = result.description.map(ingest.get_single_value)
    # the store column is tricky and can contain the artist if we parse it correctly.
    result.creator = result.creator.map(extract_artist)
    result['category'] = 'Music'
    result['subcategory'] = '' # we notably cannot get the genre for this dataset. A big weakness. Perhaps there is a way to fit it in later.
    result['title_search'] = result.title.map(search_text)
    result['creator_search'] = result.creator.map(search_text)
    result.set_index('id', inplace = True)
    return result

# %% [markdown]
# ## Import Reviews

# %%
conn = sql.connect('../products.sql')

# %%
# 130K records @ 0.6 sec = 217K records / sec
digital_music_reviews = pd.read_csv('../raw/Digital_Music.csv').drop(columns = ['Unnamed: 0'])
print(digital_music_reviews.shape)
digital_music_reviews.head(2)
# Out:
# (130434, 10)
#    rating      title                                               text  \
# 0     5.0       Nice  If i had a dollar for how many times I have pl...
# 1     5.0  Excellent  awesome sound - cant wait to see them in perso...
#
#   images        asin parent_asin                       user_id      timestamp  \
# 0     []  B004RQ2IRG  B004RQ2IRG  AFUOYIZBU3MTBOLYKOJE5Z35MBDA  1618972613292
# 1     []  B0026UZEI0  B0026UZEI0  AHGAOIZVODNHYMNCBV4DECZH42UQ  1308167525000
#
#    helpful_vote  verified_purchase
# 0             0               True
# 1             0               True

# %%
# 4.8M records @ 27.5 sec = 138K records / sec
cd_reviews = pd.read_csv('../raw/CDs_and_Vinyl.csv').drop(columns = ['Unnamed: 0'])
print(cd_reviews.shape)
# Out:
# (4827273, 10)

# %%
reviews = pd.concat([cd_reviews, digital_music_reviews])
reviews = normalize_amazon_music_reviews(reviews)
reviews.sample(3)
# Out:
#          rating                                              title  \
# 2010633     2.0                                         pink noise
# 3465510     4.0  The instrumentation on the entire CD is not th...
# 3147139     5.0                                           Grade: A
#
#                                                     review  product_id  \
# 2010633  I found it to be more annoying than relaxing. ...  B002IYDT1I
# 3465510  The instrumentation on the entire CD is not th...  B000001OQ1
# 3147139  There's nothing like that 'hoping' feeling you...  B00005OMGF
#
#                               user_id      timestamp  upvotes
# 2010633  AEZ4N5AGDWHB5RUTDIIBFITLDL3Q  1387217211000        3
# 3465510  AGO2DIZ4S4EMGCDFGANQHFBDLQOA  1468802620000        0
# 3147139  AH5PUT2TZRRZ3RVGSRLLBUBHXNIQ  1005268575000       10

# %%
# Out:
# Removed all existing music reviews.

# %%
# 5M records @ 22m 35 sec = 3.7K records / sec
clean_reviews = False
if clean_reviews:
    conn.execute("DELETE FROM review WHERE product_id IN (SELECT id FROM product WHERE category = 'Music')")
    print('Removed all existing music reviews.')
ingest.import_reviews(reviews, conn)
# Out:
# Inserting 4,957,707 records into review...
# 8.78: inserted 100,000 of 4,957,707 records (2.0%) @ 11385 records / sec
# 19.52: inserted 200,000 of 4,957,707 records (4.0%) @ 10247 records / sec
# 31.99: inserted 300,000 of 4,957,707 records (6.1%) @ 9378 records / sec
# 49.68: inserted 400,000 of 4,957,707 records (8.1%) @ 8052 records / sec
# 64.35: inserted 500,000 of 4,957,707 records (10.1%) @ 7770 records / sec
# 83.79: inserted 600,000 of 4,957,707 records (12.1%) @ 7161 records / sec
# 105.66: inserted 700,000 of 4,957,707 records (14.1%) @ 6625 records / sec
# 120.12: inserted 800,000 of 4,957,707 records (16.1%) @ 6660 records / sec
# 144.57: inserted 900,000 of 4,957,707 records (18.2%) @ 6225 records / sec
# 166.35: inserted 1,000,000 of 4,957,707 records (20.2%) @ 6011 records / sec
# 186.06: inserted 1,100,000 of 4,957,707 records (22.2%) @ 5912 records / sec
# 208.77: inserted 1,200,000 of 4,957,707 records (24.2%) @ 5748 records / sec
# 230.60: inserted 1,300,000 of 4,957,707 records (26.2%) @ 5637 records / sec
# 261.78: inserted 1,400,000 of 4,957,707 records (28.2%) @ 5348 records / sec
# 282.22: inserted 1,500,000 of 4,957,707 records (30.3%) @ 5315 records / sec
# 303.51: inserted 1,600,000 of 4,957,707 records (32.3%) @ 5272 records / sec
# 333.40: inserted 1,700,000 of 4,957,707 records (34.3%) @ 5099 records / sec
# 355.52: inserted 1,800,000 of 4,957,707 records (36.3%) @ 5063 records / sec
# 385.67: inserted 1,900,000 of 4,957,707 records (38.3%) @ 4926 records / sec
# 407.86: inserted 2,000,000 of 4,957,707 records (40.3%) @ 4904 records / sec
# 428.82: inserted 2,100,000 of 4,957,707 records (42.4%) @ 4897 records / sec
# 453.46: inserted 2,200,000 of 4,957,707 records (44.4%) @ 4852 records / sec
# 487.16: inserted 2,300,000 of 4,957,707 records (46.4%) @ 4721 records / sec
# 514.39: inserted 2,400,000 of 4,957,707 records (48.4%) @ 4666 records / sec
# 549.96: inserted 2,500,000 of 4,957,707 records (50.4%) @ 4546 records / sec
# 574.03: inserted 2,600,000 of 4,957,707 records (52.4%) @ 4529 records / sec
# 598.42: inserted 2,700,000 of 4,957,707 records (54.5%) @ 4512 records / sec
# 626.71: inserted 2,800,000 of 4,957,707 records (56.5%) @ 4468 records / sec
# 667.28: inserted 2,900,000 of 4,957,707 records (58.5%) @ 4346 records / sec
# 699.94: inserted 3,000,000 of 4,957,707 records (60.5%) @ 4286 records / sec
# 732.02: inserted 3,100,000 of 4,957,707 records (62.5%) @ 4235 records / sec
# 759.79: inserted 3,200,000 of 4,957,707 records (64.5%) @ 4212 records / sec
# 783.34: inserted 3,300,000 of 4,957,707 records (66.6%) @ 4213 records / sec
# 816.00: inserted 3,400,000 of 4,957,707 records (68.6%) @ 4167 records / sec
# 850.55: inserted 3,500,000 of 4,957,707 records (70.6%) @ 4115 records / sec
# 894.00: inserted 3,600,000 of 4,957,707 records (72.6%) @ 4027 records / sec
# 928.41: inserted 3,700,000 of 4,957,707 records (74.6%) @ 3985 records / sec
# 954.06: inserted 3,800,000 of 4,957,707 records (76.6%) @ 3983 records / sec
# 991.08: inserted 3,900,000 of 4,957,707 records (78.7%) @ 3935 records / sec
# 1024.18: inserted 4,000,000 of 4,957,707 records (80.7%) @ 3906 records / sec
# 1057.90: inserted 4,100,000 of 4,957,707 records (82.7%) @ 3876 records / sec
# 1088.29: inserted 4,200,000 of 4,957,707 records (84.7%) @ 3859 records / sec
# 1119.57: inserted 4,300,000 of 4,957,707 records (86.7%) @ 3841 records / sec
# 1151.73: inserted 4,400,000 of 4,957,707 records (88.8%) @ 3820 records / sec
# 1186.63: inserted 4,500,000 of 4,957,707 records (90.8%) @ 3792 records / sec
# 1224.13: inserted 4,600,000 of 4,957,707 records (92.8%) @ 3758 records / sec
# 1258.12: inserted 4,700,000 of 4,957,707 records (94.8%) @ 3736 records / sec
# 1297.06: inserted 4,800,000 of 4,957,707 records (96.8%) @ 3701 records / sec
# 1330.41: inserted 4,900,000 of 4,957,707 records (98.8%) @ 3683 records / sec
# 1355.05: inserted 4,957,707 of 4,957,707 records (100.0%) @ 3659 records / sec

# %% [markdown]
# ## Import Products

# %%
digital_music_data = pd.read_csv('../raw/meta_Digital_Music.csv').drop(columns = ['Unnamed: 0'])
digital_music_data.head(2)
# Out:
#    main_category                                             title  \
# 0  Digital Music                                 Baja Marimba Band
# 1  Digital Music  '80s Halloween-All Original Artists & Recordings
#
#    average_rating  rating_number features description  price  \
# 0             4.9              8       []          []    NaN
# 1             5.0              3       []          []  14.98
#
#                                               images videos  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...     []
# 1  [{'thumb': 'https://m.media-amazon.com/images/...     []
#
#                                                store categories  \
# 0                                                NaN         []
# 1  Love and Rockets  (Artist),     Duran Duran  (...         []
#
#                                              details parent_asin  \
# 0      {'Date First Available': 'February 28, 2010'}  B000V87RP2
# 1  {'Package Dimensions': '5.55 x 4.97 x 0.54 inc...  B0062F0MJQ
#
#    bought_together
# 0              NaN
# 1              NaN

# %%
cd_data = pd.read_csv('../raw/meta_CDs_and_Vinyl.csv').drop(columns = ['Unnamed: 0'])

# %%
product_data = pd.concat([digital_music_data, cd_data])
product_data_normalized = normalize_amazon_music_data(product_data)
product_data_normalized.sample(10)
# Out:
#            category                                              title  \
# id
# B001W6Q4BU    Music                        The Kinks Choral Collection
# B000008JCW    Music                                              March
# B00701QV0A    Music                                     Eye In The Sky
# B000TJ71EK    Music                               Sings Operatic Arias
# B000BY8MSC    Music                              Caribbean Steel Drums
# B09JJCC89T    Music                       A Tear In The Fabric of Life
# B000I8X5TM    Music                                             Chaney
# B000003FHA    Music                               Pops Christmas Party
# B018X0VINQ    Music                               Servitude by Imports
# B001GC8V6Q    Music  Grand Collection. Dmitri Hvorostovsky. Vol. 2....
#
#                                                   description  \
# id
# B001W6Q4BU  Product Description, After massively successfu...
# B000008JCW  1. No Myth 4:11 2. Half Harvest 4:04 3. This a...
# B00701QV0A
# B000TJ71EK  The brilliant coloratura soprano Roberta Peter...
# B000BY8MSC  Sounds wonderful by the pool or while sipping ...
# B09JJCC89T  Surprise EP drop from Knocked Loose ahead of t...
# B000I8X5TM  Songs: 1. Me estoy Muriendo Por Dentro 2. Me E...
# B000003FHA  The 1959 Boston Pops Christmas "Living Stereo"...
# B018X0VINQ
# B001GC8V6Q
#
#                                                       creator  \
# id
# B001W6Q4BU                                         Ray Davies
# B000008JCW                                       Michael Penn
# B00701QV0A  Alan Parsons Project   Alan Parsons Symphonic ...
# B000TJ71EK                                     Roberta Peters
# B000BY8MSC                                         Lifescapes
# B09JJCC89T                                      Knocked Loose
# B000I8X5TM                                    Conjunto Chaney
# B000003FHA       Arthur Fiedler and the Boston Pops Orchestra
# B018X0VINQ                                    Aversions Crown
# B001GC8V6Q                               Hvorostovsky, Dmitri
#
#                  release_date subcategory  \
# id
# B001W6Q4BU     March 21, 2009
# B000008JCW      July 26, 2006
# B00701QV0A   January 21, 2012
# B000TJ71EK      July 20, 2007
# B000BY8MSC   November 2, 2005
# B09JJCC89T   October 14, 2021
# B000I8X5TM  September 2, 2006
# B000003FHA   December 7, 2006
# B018X0VINQ       May 23, 2020
# B001GC8V6Q  September 5, 2012
#
#                                                  title_search  \
# id
# B001W6Q4BU                              kinkschoralcollection
# B000008JCW                                              march
# B00701QV0A                                           eyeinsky
# B000TJ71EK                                 singsoperaticarias
# B000BY8MSC                                caribbeansteeldrums
# B09JJCC89T                                atearinfabricoflife
# B000I8X5TM                                             chaney
# B000003FHA                                 popschristmasparty
# B018X0VINQ                                 servitudebyimports
# B001GC8V6Q  grandcollectiondmitrihvorostovskyvol2oldrussia...
#
#                                            creator_search
# id
# B001W6Q4BU                                      raydavies
# B000008JCW                                    michaelpenn
# B00701QV0A  alanparsonsprojectalanparsonssymphonicproject
# B000TJ71EK                                  robertapeters
# B000BY8MSC                                     lifescapes
# B09JJCC89T                                   knockedloose
# B000I8X5TM                                 conjuntochaney
# B000003FHA            arthurfiedlerandbostonpopsorchestra
# B018X0VINQ                                 aversionscrown
# B001GC8V6Q                             dmitrihvorostovsky

# %% [markdown]
# ### Handling Duplicates
# Interestingly, some music data conflicts with existing product data, resulting in an error on insertion.
#
# The conflicting data appears to be books in CD format that are classified as audio CDs. We are only interested in music audio CDs, so it's best to remove these from our music data.

# %%
dupes = ingest.find_duplicates(product_data_normalized, 'product', conn)
print('Duplicate products already in the database:')
ids = ','.join(['?'] * len(dupes))
pd.read_sql(f"SELECT * FROM product WHERE id IN ({ids})", conn, params = dupes.index)
# Out:
# Duplicate products already in the database:
#             id                                              title  \
# 0   075406364X                      Afterdark: The Dream Snatcher
# 1   0754084507           Watching Out (A Fran Varady crime novel)
# 2   0786175621                                     V for Vendetta
# 3   0787106186  Soaring With the Phoenix: Renewing the Vision,...
# 4   082883279X  Assimil Language Course / Le Danois sans Peine...
# 5   0867176865                                      Color Phonics
# 6   0875098681                 The Tozer CD-ROM Library (Version)
# 7   0886902975  Rich Hall's Vanishing America/Audio Cassette/#...
# 8   0967951615                          Sunday Morning: The Novel
# 9   0970863330  Indigo Dreams: Adult Relaxation-Guided Meditat...
# 10  0970863349  Indigo Dreams: Relaxation and Stress Managemen...
# 11  0970863365  Indigo Ocean Dreams: 4 Children's Stories Desi...
# 12  097086339X  Indigo Teen Dreams: Guided Relaxation Techniqu...
# 13  1402581963              Winston Churchill: Man of the Century
# 14  1402586582                                       Last Citadel
# 15  1570193630            Master Detectives (10-Hour Collections)
# 16  1844560368                                        Vanity Fair
# 17  1844560414                                       Bobby Robson
# 18  1881405230  Healing Trauma: Guided Imagery for Posttraumat...
# 19  1881405338  A Meditation to Help You Improve Self-Confiden...
# 20  1881405362                     A Meditation to Help Ease Pain
# 21  1881405427  Affirmations for Mind, Body and Spirit (Health...
# 22  1881451585                  Prayer: Manifest a State of Grace
# 23  5558889551  A Contemplative Rosary: Praying the Mysteries ...
# 24  6308035971                                            Fanfare
# 25  B00005N9CI       Management Tools 2001 : An executive's guide
# 26  B00005UVHG  Probing As The Future Catches You -- Juan Enri...
# 27  B00005Y1O1  Effective Listening And Feedback -- Improving ...
# 28  B00009MBYK                                            99 Cows
# 29  B000ENWS6M                          Mythic Time, Stone Circle
# 30  B000F00K46                      The Power of Shamanic Healing
# 31  B000FBUG62                          The New PsychoCybernetics
# 32  B000IXOB72                Moderatto En Directo ... Ponte Loco
# 33  B000JM5NWE                                     Rompecorazones
# 34  B000KJ5G1Y                      Shappy! Poet/Comedian/A**hole
# 35  B000LJ1AWM  The Lie of Ascension. Be Now! Releasing the Cy...
# 36  B000NWBJUA  Verses of Victory for Christian Success! ** En...
# 37  B000NXAONC                    Snow White and the Seven Dwarfs
# 38  B000RCH0KO                    Muzzy -- A Video Spanish Course
#
#                                          title_search  \
# 0                              afterdarkdreamsnatcher
# 1                    watchingoutafranvaradycrimenovel
# 2                                        vforvendetta
# 3   soaringwithphoenixrenewingvisionrevivingspirit...
# 4   assimillanguagecourseledanoissanspeinedanishfo...
# 5                                        colorphonics
# 6                            tozercdromlibraryversion
# 7         richhallsvanishingamericaaudiocassette20090
# 8                                  sundaymorningnovel
# 9   indigodreamsadultrelaxationguidedmeditationrel...
# 10  indigodreamsrelaxationandstressmanagementbedti...
# 11  angerandanxietywhileincreasingselfesteemandsel...
# 12  angerandanxietywhileincreasingselfesteemandsel...
# 13                       winstonchurchillmanofcentury
# 14                                        lastcitadel
# 15                  masterdetectives10hourcollections
# 16                                         vanityfair
# 17                                        bobbyrobson
# 18  healingtraumaguidedimageryforposttraumaticstre...
# 19  ameditationtohelpyouimproveselfconfidenceandre...
# 20                          ameditationtohelpeasepain
# 21     bodyandspirithealthjourneysaffirmationsformind
# 22                        prayermanifestastateofgrace
# 23  songiconsacontemplativerosaryprayingmysteriesw...
# 24                                            fanfare
# 25               managementtools2001anexecutivesguide
# 26  probingasfuturecatchesyoujuanenriquezexploresg...
# 27  effectivelisteningandfeedbackimprovinghowyouli...
# 28                                             99cows
# 29                              stonecirclemythictime
# 30                             powerofshamanichealing
# 31                               newpsychocybernetics
# 32                        moderattoendirectoponteloco
# 33                                     rompecorazones
# 34                            shappypoetcomedianahole
# 35          lieofascensionbenowreleasingcycleofescape
# 36  versesofvictoryforchristiansuccessencouragingi...
# 37                            snowwhiteandsevendwarfs
# 38                           muzzyavideospanishcourse
#
#                                               creator  \
# 0                                        Annie Dalton
# 1                                         Ann Granger
# 2                                                 nan
# 3       Marshall Goldsmith, Beverly Kaye, Ken Shelton
# 4                                      United Nations
# 5                                                 nan
# 6                                         A. W. Tozer
# 7                                                 nan
# 8                                       Alan Sillitoe
# 9                                           Lori Lite
# 10                                    Michael Cropper
# 11                                     Kathy Paterson
# 12                                                nan
# 13                                     Louis H. Meyer
# 14                                                nan
# 15                                      Fred M. White
# 16                                     Graydon Carter
# 17                                     David Hartrick
# 18                                Belleruth Naparstek
# 19  Marilyn H. Oermann, PhD, RN, FAAN, Kathleen T....
# 20                    CULADASA, Matthew Immergut, PhD
# 21                                     Lauren Porchia
# 22                                    Catholic Church
# 23                                  Gloria Hutchinson
# 24                                       Pamela Cowen
# 25                                                nan
# 26                                                nan
# 27                                    Christian Olsen
# 28                                       Lisa Wheeler
# 29                                       Anthony Tuck
# 30                                     Kristin Madden
# 31                                      Maxwell Maltz
# 32                                    Pamela Gillilan
# 33                               Rachel Renée Russell
# 34                                      George Orwell
# 35                                   Robert E. Pettit
# 36                                                nan
# 37               Walt Disney, Walt Disney Productions
# 38                                                nan
#
#                                     creator_search  \
# 0                                      anniedalton
# 1                                       anngranger
# 2                                              nan
# 3           marshallgoldsmithbeverlykayekenshelton
# 4                                    unitednations
# 5                                              nan
# 6                                          awtozer
# 7                                              nan
# 8                                     alansillitoe
# 9                                         lorilite
# 10                                  michaelcropper
# 11                                   kathypaterson
# 12                                             nan
# 13                                     louishmeyer
# 14                                             nan
# 15                                      fredmwhite
# 16                                   graydoncarter
# 17                                   davidhartrick
# 18                              belleruthnaparstek
# 19  marilynhoermannphdrnfaankathleentheinrichphdrn
# 20                         culadasamatwimmergutphd
# 21                                   laurenporchia
# 22                                  catholicchurch
# 23                                gloriahutchinson
# 24                                     pamelacowen
# 25                                             nan
# 26                                             nan
# 27                                  christianolsen
# 28                                     lisawheeler
# 29                                     anthonytuck
# 30                                   kristinmadden
# 31                                    maxwellmaltz
# 32                                  pamelagillilan
# 33                              rachelreneerussell
# 34                                    georgeorwell
# 35                                   robertepettit
# 36                                             nan
# 37                 waltdisneyproductionswaltdisney
# 38                                             nan
#
#                                             publisher  \
# 0                                                None
# 1                                         Hachette UK
# 2                                                None
# 3                                    Nicholas Brealey
# 4                                                  UN
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                    HarperCollins UK
# 9                                    Stress Free Kids
# 10                                             Lennex
# 11                        Pembroke Publishers Limited
# 12  Unitarian Universalist Association of Congrega...
# 13                                               None
# 14                                               None
# 15                                            DigiCat
# 16                                    Harry N. Abrams
# 17                                   Pitch Publishing
# 18                                             Bantam
# 19                        Springer Publishing Company
# 20                                     Hay House, Inc
# 21                                               None
# 22                                   USCCB Publishing
# 23                                               None
# 24                   Third Millennium Information Ltd
# 25                                               None
# 26                                               None
# 27                                       Vincent Noot
# 28                          Houghton Mifflin Harcourt
# 29                                    Wheatmark, Inc.
# 30                                Llewellyn Worldwide
# 31                                            Penguin
# 32                                    Dufour Editions
# 33                                             Molino
# 34                                Singel Uitgeverijen
# 35                                          iUniverse
# 36                                               None
# 37                                               None
# 38                                               None
#
#                                           description category  \
# 0   AFTERDARK is threatened by one man's destructi...    Books
# 1   There's trouble ahead for Fran Varady... Just ...    Books
# 2                                                None    Books
# 3   Great leaders are great learners More than a d...    Books
# 4                                                None    Books
# 5                                                None    Books
# 6   The Tozer CD-ROM Library is a searchable datab...    Books
# 7                                                None    Books
# 8   "Working all week at the lathe leaves Arthur S...    Books
# 9   Children love to unwind and relax with this fu...    Books
# 10  In this book, we have hand-picked the most sop...    Books
# 11  "This topical book begins with an appeal to te...    Books
# 12                                               None    Books
# 13                                               None    Books
# 14                                               None    Books
# 15  DigiCat Publishing presents to you a collectio...    Books
# 16  Offers the history of "Vanity Fair" by present...    Books
# 17  Silver Linings examines an historic and unforg...    Books
# 18  If you or someone you love has suffered a trau...    Books
# 19  This timely volume in the Springer Annual Revi...    Books
# 20  The Mind Illuminated is a comprehensive, acces...    Books
# 21  Your restoration is rooted in the communion of...    Books
# 22  As hunger for the faith continues to grow, Pop...    Books
# 23  Each mystery begins with a personal reflection...    Books
# 24  This illustrated volume, published in conjunct...    Books
# 25                                               None    Books
# 26                                               None    Books
# 27  Become better at communicating by enhancing yo...    Books
# 28  Rhyming tale of Cowboy Gene and Cowgirl Sue, w...    Books
# 29                                               None    Books
# 30  This groundbreaking book offers a complete "he...    Books
# 31  With over 30 million copies sold since its ori...    Books
# 32  Pamela Gillilan was born in London in 1918, ma...    Books
# 33  Nikki te da la pista definitiva para saber si ...    Books
# 34  Nieuwspraak, Big Brother, het vocabulaire uit ...    Books
# 35  There Is a Place You Can Go - That place is a ...    Books
# 36                                               None    Books
# 37  Little Critter is on his first Little League t...    Books
# 38                                               None    Books
#
#                          subcategory release_date
# 0                  Children's dreams      2001-06
# 1                            Fiction   2010-01-07
# 2                                nan         None
# 3               Business & Economics   2010-11-26
# 4                  Political Science   2007-11-02
# 5                                nan         None
# 6                                nan         None
# 7        Booksellers and bookselling         1986
# 8           Black humor (Literature)         2006
# 9                          Self-Help         2008
# 10                               nan      2013-01
# 11                         Education         2010
# 12                               nan         None
# 13                     Great Britain         1972
# 14                               nan         None
# 15                           Fiction   2022-05-17
# 16                       Photography   2013-10-15
# 17                               nan   2021-06-07
# 18                        Psychology   2007-12-18
# 19                           Medical   2006-11-08
# 20               Body, Mind & Spirit   2017-01-03
# 21                               nan   2019-07-22
# 22                          Religion         2006
# 23                          Religion         1991
# 24                               Art         2003
# 25                               nan         None
# 26                               nan         None
# 27                         Self-Help   2019-02-08
# 28                  Juvenile Fiction         2002
# 29                           Fiction   2015-11-15
# 30               Body, Mind & Spirit   2015-01-08
# 31                         Self-Help   2002-12-03
# 32  Poetry in English, 1945- - Texts         1986
# 33                  Juvenile Fiction   2014-03-27
# 34                           Fiction   2013-05-16
# 35               Body, Mind & Spirit   2010-09-22
# 36                               nan         None
# 37                  Dwarfs (Persons)         1993
# 38                               nan         1988

# %%
product_data_normalized.drop(index = dupes.index, inplace = True)
ingest.find_duplicates(product_data_normalized, 'product', conn)
# Out:
# Empty DataFrame
# Columns: [category, title, description, creator, release_date, subcategory, title_search, creator_search]
# Index: []

# %%
ingest.import_products(product_data_normalized, conn)

# %% [markdown]
# ### Verify

# %%
pd.read_sql("SELECT COUNT(*) AS albums FROM product WHERE category = 'Music'", conn)
# Out:
#    albums
# 0  768224

# %%
pd.read_sql("SELECT category, COUNT(*) AS products FROM product GROUP BY category", conn)
# Out:
#   category  products
# 0    Books    212397
# 1    Music    768224

# %%
print("Album examples")
pd.read_sql("SELECT * FROM product WHERE category = 'Music' LIMIT 5", conn)
# Out:
# Album examples
#            id                                              title  \
# 0  0001046314                               A Woman of Substance
# 1  0001046519  The Importance of Being Earnest Complete & Una...
# 2  0001048236               The Sherlock Holmes Audio Collection
# 3  0001048252                              All the Pretty Horses
# 4  0001048791  The Crucible Performed by Stuart Pankin, Jerom...
#
#                                        title_search  \
# 0                                 awomanofsubstance
# 1        importanceofbeingearnestcompleteunabridged
# 2                     sherlockholmesaudiocollection
# 3                                   allprettyhorses
# 4  jeromedempseycastcrucibleperformedbystuartpankin
#
#                        creator          creator_search publisher  \
# 0      Barbara Taylor Bradford   barbarataylorbradford
# 1  Oscar Wilde   Trevor Millum  oscarwildetrevormillum
# 2
# 3              Cormac McCarthy          cormacmccarthy
# 4                Arthur Miller            arthurmiller
#
#                                          description category subcategory  \
# 0  This is the first in a saga of books about Emm...    Music
# 1                                                       Music
# 2                                                       Music
# 3  The story of John Grady Cole, who at 16 finds ...    Music
# 4                                                       Music
#
#         release_date
# 0   January 30, 2007
# 1    October 7, 2006
# 2  February 16, 2007
# 3   January 30, 2007
# 4   January 26, 2007

# %%
pd.read_sql("SELECT COUNT(*) AS reviews FROM review", conn)
# Out:
#    reviews
# 0  7959678

# %%
pd.read_sql("SELECT category, COUNT(*) as reviews FROM review r JOIN product p ON r.product_id = p.id GROUP BY category", conn)
# Out:
#   category  reviews
# 0    Books  2597367
# 1    Music  4903858

# %%
print("Review examples:")
pd.read_sql("SELECT * FROM review r JOIN product p ON r.product_id = p.id WHERE category = 'Music' LIMIT 5", conn)
# Out:
# Review examples:
#                         user_id  product_id  \
# 0  AFLPX7J55FASTRFVCTHBS5NJKGAA  0001046314
# 1  AF6QIUNWC2QOTXT7DFM4E3WWZR4A  0001046519
# 2  AFUTBB27LNTCQPZS7Q77WVQUKCBA  0001048236
# 3  AGTHUDIRWR5TUPG564RDXNVF27AQ  0001048252
# 4  AFIC6SKUPM64WJEFRNNFW75WYO3A  0001048252
#
#                                    title  \
# 0                               MNReview
# 1  This Play Gets No Better Than This...
# 2                             Five Stars
# 3                 literary masterpiece..
# 4          Just finished- first thoughts
#
#                                               review  rating  upvotes  \
# 0  Great for a quick tape of the best Bradford bo...       4        0
# 1  Oscar Wilde's masterpiece, this play has many,...       5        1
# 2                                 Just as advertised       5        0
# 3  perhaps the most memorable of the Border Trilo...       5        2
# 4  I've only just finished Moby Dick before readi...       4        0
#
#    downvotes      timestamp          id  \
# 0          0  1191318038000  0001046314
# 1          0  1489635021000  0001046519
# 2          0  1501871291329  0001048236
# 3          0  1178655330000  0001048252
# 4          0  1176830183000  0001048252
#
#                                                title  \
# 0                               A Woman of Substance
# 1  The Importance of Being Earnest Complete & Una...
# 2               The Sherlock Holmes Audio Collection
# 3                              All the Pretty Horses
# 4                              All the Pretty Horses
#
#                                  title_search                      creator  \
# 0                           awomanofsubstance      Barbara Taylor Bradford
# 1  importanceofbeingearnestcompleteunabridged  Oscar Wilde   Trevor Millum
# 2               sherlockholmesaudiocollection
# 3                             allprettyhorses              Cormac McCarthy
# 4                             allprettyhorses              Cormac McCarthy
#
#            creator_search publisher  \
# 0   barbarataylorbradford
# 1  oscarwildetrevormillum
# 2
# 3          cormacmccarthy
# 4          cormacmccarthy
#
#                                          description category subcategory  \
# 0  This is the first in a saga of books about Emm...    Music
# 1                                                       Music
# 2                                                       Music
# 3  The story of John Grady Cole, who at 16 finds ...    Music
# 4  The story of John Grady Cole, who at 16 finds ...    Music
#
#         release_date
# 0   January 30, 2007
# 1    October 7, 2006
# 2  February 16, 2007
# 3   January 30, 2007
# 4   January 30, 2007

# %%
print("Most reviewed albums:")
pd.read_sql_query("""
SELECT p.title AS album, p.creator AS artist, COUNT(*) AS reviews
FROM review r JOIN product p ON r.product_id = p.id
WHERE category = 'Music'
GROUP BY p.title, p.creator ORDER BY reviews DESC LIMIT 10
""", conn)
# Out:
# Most reviewed albums:
#                                      album              artist  reviews
# 0                                       25               Adele     5145
# 1                   That's Christmas To Me          Pentatonix     3648
# 2                                Traveller     Chris Stapleton     3241
# 3  Hamilton O.B.C.R.       Explicit Lyrics  Lin-Manuel Miranda     3096
# 4                         Oscd Ad Adele 21               Adele     2953
# 5                                 Partners    Barbra Streisand     2933
# 6                                     1989        Taylor Swift     2602
# 7                        I Dreamed A Dream         Susan Boyle     2309
# 8                                   Fallen         Evanescence     2161
# 9                                 Thriller     Michael Jackson     2004

# %%
print("Most reviewed artists:")
pd.read_sql_query("""
SELECT p.creator AS artist, COUNT(*) AS reviews
FROM review r JOIN product p ON r.product_id = p.id
WHERE category = 'Music'
GROUP BY p.creator ORDER BY reviews DESC LIMIT 10
""", conn)
# Out:
# Most reviewed artists:
#                artist  reviews
# 0     Various Artists   109827
# 1                        41886
# 2     VARIOUS ARTISTS    32563
# 3             Various    29866
# 4         The Beatles    25645
# 5   Rated:    Unrated    24659
# 6       Elvis Presley    16596
# 7          Pink Floyd    15711
# 8  The Rolling Stones    12765
# 9           Bob Dylan    12607

# %% [markdown]
# ### Close Connection

# %%
conn.close()
