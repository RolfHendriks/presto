# %% [markdown]
# # Data Sanitization
#
# This notebook includes utilities for sanitizing unwanted data.
#
# Though it is best to avoid unwanted data by filtering low-quality data out of data ingest workflows, being left with unwanted data is an unavoidable reality. This is especially true when using sqlite, which does not cascade deletions. For example, removing products will result in orphaned product reviews despite the foreign key constraint on review.product_id.

# %%
import sqlite3 as sql
import pandas as pd

def find_orphaned_reviews(conn: sql.Connection, ids_only = False) -> pd.DataFrame:
    selection = "DISTINCT(product_id)" if ids_only else "*"
    return pd.read_sql_query(f"""
    WITH product_ids AS (SELECT id FROM product)
    SELECT {selection} FROM review WHERE product_id NOT IN product_ids
    """, conn)

def remove_orphaned_reviews(conn: sql.Connection):
    # Note: tweaking the below query to creating a list of product ids NOT in the product table does not improve performance
    conn.execute("""
    WITH product_ids AS (SELECT id FROM product)
    DELETE FROM review WHERE product_id NOT IN product_ids
    """)

# %%
conn = sql.connect('../products.sql')

# %%
# retrieve orphaned reviews so we can verify and conduct EDA before deleting
orphaned_reviews = find_orphaned_reviews(conn)

# %%
orphaned_reviews
# Out:
#                              user_id  product_id  \
# 0                     A223508619VLG1  B0007F8Q9K
# 1                     A2K3XIR3EA9L5O  B0007F8Q9K
# 2                     A1E8EIKF5T05BO  B0007F8Q9K
# 3                     A2TXR85WQLE32N  B0007F8Q9K
# 4                     A19Q6JEEEBNOAU  B0007F8Q9K
# ...                              ...         ...
# 458448  AGLQY3IGI43MK7TQJ4SQNCPGFLOQ  B0019VSNNA
# 458449  AGXQUTQBTALZ7ZBCMEL4A6MIPFJA  B07C88R67M
# 458450  AHCUX5TVEU2OH6CVZGWPCBV4DFPA  1938774272
# 458451  AEOA6Z2MGYKYXE2ZDSXZBGYNO7ZQ  B0009PUCUE
# 458452  AHXADQUCWESPUD63SMNEGCHOYGRA  B00008NG9M
#
#                                                     title  \
# 0       40 Years of Life; Lincoln Reconsidered fires t...
# 1                                   Lincoln for our times
# 2                     Not your ordinary Lincoln biography
# 3                                Reconsidering Lincoln...
# 4                                    Lincoln and his time
# ...                                                   ...
# 458448                              MLMers listen to Jim.
# 458449                                      Awesome Album
# 458450                                         Four Stars
# 458451                 Enjoyed listening to this program.
# 458452                                  mostly delightful
#
#                                                    review  rating  upvotes  \
# 0       Lincoln Reconsidered is a collection of provac...       5       25
# 1       Lincoln Reconsidered is a series of essays wri...       4        0
# 2       According to the author's Preface, the publish...       5        0
# 3       Famous Lincoln scholar David Herbert Donald fi...       4        0
# 4       For the mpost part any book by David Donald is...       4        1
# ...                                                   ...     ...      ...
# 458448  I strongly believe that every MLM'er should li...       5        2
# 458449  Amazing Album🖤 If you are a BTS fan you will a...       5        0
# 458450  I use this cd every day,it meets all of my exp...       4        0
# 458451  It fit my needs on hearing how you can be succ...       4        0
# 458452  After having listened to the Reduced Shakespea...       4        2
#
#         downvotes      timestamp
# 0               3      913852800
# 1               0     1357776000
# 2               0     1356739200
# 3               0     1338940800
# 4               1     1187827200
# ...           ...            ...
# 458448          0  1312210738000
# 458449          0  1534056358574
# 458450          0  1429715098000
# 458451          0  1389091102000
# 458452          0  1294248926000
#
# [458453 rows x 8 columns]

# %%
remove_orphaned_reviews(conn)
conn.commit()

# %%
conn.close()
