# %% [markdown]
# # Product Recommendation - Stress Test
# This time, let's make a recommendation for a very popular product to see if our algorithm can handle the load of the high number of reviews.
#
# Note: this case required filtering of reviews to avoid overloading the system and also improve relevance as a side effect. The changes have been rolled into the shared workflow used by all worksheets.

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload

import matplotlib.pyplot as plt
import pandas as pd

import shared.query as q
import shared.viz as viz
import shared.reviews as rev

viz.set_style()

# %%
conn = q.connect('data/products.sql')

# %%
products = q.query("""
SELECT id, p.title, creator, description, release_date, COUNT(*) AS reviews, category, subcategory
FROM review r JOIN product p ON r.product_id = p.id
GROUP BY product_id
ORDER BY reviews DESC LIMIT 100
""", conn)
# Out:
# SELECT id, p.title, creator, description, release_date, COUNT(*) AS reviews, category, subcategory
# FROM review r JOIN product p ON r.product_id = p.id
# GROUP BY product_id
# ORDER BY reviews DESC LIMIT 100
# : 100 results in 23.696 seconds

# %%
products[:20]
# Out:
#             id                                              title  \
# 0   B000IEZE3G              Harry Potter and The Sorcerer's Stone
# 1   B016WW10SA                                                 25
# 2   B000ILIJE0                    The Hobbit There and Back Again
# 3   B000NWU3I4  The Hobbitt, or there and back again; illustra...
# 4   B000Q032UY                 The Hobbit or There and Back Again
# 5   B000GQG5MA               The Hobbit; Or, There and Back Again
# 6   B000NDSX6C                                         The Hobbit
# 7   B000P1QRII                                          The Giver
# 8   B00NEJ7MMI                             That's Christmas To Me
# 9   B0000YSH5G                                              Holes
# 10  B000PCESRE                             The Catcher in the Rye
# 11  B000PMCF1A  The Catcher in the Rye [Audiobook] [Cd] [Unabr...
# 12  B000I3NFKG                             THE CATCHER IN THE RYE
# 13  B000J521DU                     ERAGON: INHERITANCE, BOOK ONE.
# 14  B000NPEWHE            Harry Potter and the Chamber of Secrets
# 15  B000MOOAJG                                     Atlas Shrugged
# 16  B013JLBPGE            Hamilton O.B.C.R.       Explicit Lyrics
# 17  B0006IU3ZS  Unfit for Command: Swift Boat Veterans Speak O...
# 18  B004EBT5CU                                   Oscd Ad Adele 21
# 19  B000N76ZCC             Harry Potter & the Prisoner of Azkaban
#
#                       creator  \
# 0               J. K. Rowling
# 1                       Adele
# 2   John Ronald Reuel Tolkien
# 3            J. R. R. Tolkien
# 4            J. R. R. Tolkien
# 5                         nan
# 6            J. R. R. Tolkien
# 7                  Lois Lowry
# 8                  Pentatonix
# 9                Louis Sachar
# 10                        nan
# 11               John Donovan
# 12              J.D. Salinger
# 13        Christopher Paolini
# 14              J. K. Rowling
# 15                        nan
# 16         Lin-Manuel Miranda
# 17    BusinessNews Publishing
# 18                      Adele
# 19            Lisa S. Brenner
#
#                                           description        release_date  \
# 0   Celebrate 20 years of Harry Potter magic! Harr...          2014-01-09
# 1                                                                    None
# 2   The adventures of the well-to-do hobbit, Bilbo...                1966
# 3   Bilbo Baggins, a respectable, well-to-do hobbi...                2013
# 4   Celebrating 75 years of one of the world's mos...                2012
# 5                                                None                None
# 6   Celebrating 75 years of one of the world's mos...                2012
# 7   Given his lifetime assignment at the Ceremony ...          2014-07-01
# 8                                             Used CD  September 13, 2014
# 9   #1 NEW YORK TIMES BESTSELLER • NEWBERY MEDAL W...          2011-06-01
# 10                                               None                None
# 11  I’ll Get There. It Better Be Worth the Trip. i...          2010-09-08
# 12  Anyone who has read J. D. Salinger's New Yorke...          1951-07-16
# 13  One boy . . . One dragon . . . A world of adve...                2005
# 14                    Witchcraft, wizardry - fiction.                1999
# 15                                               None                None
# 16  "Hamilton" - which transferred to Broadway fol...      August 7, 2015
# 17  The must-read summary of John E. O’Neill and J...          2017-01-30
# 18  21, is the eagerly awaited sophomore album fro...   November 29, 2010
# 19  Through classroom activities, wizard rock conc...          2015-06-11
#
#     reviews category          subcategory
# 0      6711    Books     Juvenile Fiction
# 1      4354    Music
# 2      4331    Books    Adventure stories
# 3      4316    Books              Fiction
# 4      4266    Books     Juvenile Fiction
# 5      4166    Books                  nan
# 6      4118    Books     Juvenile Fiction
# 7      3770    Books     Juvenile Fiction
# 8      3629    Music
# 9      3512    Books     Juvenile Fiction
# 10     3208    Books                  nan
# 11     3199    Books  Young Adult Fiction
# 12     3189    Books              Fiction
# 13     3112    Books              Dragons
# 14     3099    Books     Juvenile Fiction
# 15     3078    Books                  nan
# 16     3073    Music
# 17     2977    Books    Political Science
# 18     2932    Music
# 19     2919    Books   Literary Criticism

# %%
search_term = "Harry Potter and The Sorcerer's Stone"

print(f"Books like {repr(search_term)}")
recommendations = q.get_recommendations('Books', search_term, conn, exact_match = True, verbosity = 1)
# Out:
# Books like "Harry Potter and The Sorcerer's Stone"
# find_products: 1 results in 0.016 seconds
# 0.0175: Found 1 products
# SELECT * FROM review WHERE product_id IN (?)
# ['B000IEZE3G']
# 0.105: Got 6711 reviews
# 0.106: Filtered 5984 helpful reviews
# 0.621: Got 44985 related reviews of 20717 products by 3205 users
# 0.622: Filtered 40598 helpful related reviews
# 0.637: Filtered 6497 related reviews by user and/or product
# 0.646: Created ratings table for 1000 products by 100 users
# 0.662: Calculated similarities
# 0.73: Removed 98 duplicate editions of the same product
# 0.73: Added product details

# %%
product = recommendations['result']
product
# Out:
# id                                                     B000IEZE3G
# reviews                                                      6711
# title                       Harry Potter and The Sorcerer's Stone
# creator                                             J. K. Rowling
# publisher                                   Bloomsbury Publishing
# description     Celebrate 20 years of Harry Potter magic! Harr...
# release_date                                           2014-01-09
# category                                                    Books
# subcategory                                      Juvenile Fiction
# Name: 0, dtype: object

# %%
all_reviews = rev.sort_reviews(q.get_reviews(product.id, conn))
all_reviews
# Out:
# SELECT * FROM review WHERE product_id IN (?)
# ['B000IEZE3G']
# get_reviews: 6711 results in 0.061 seconds
#              user_id  product_id  \
# 3004  A3IB1W0SVED0Z3  B000IEZE3G
# 3008  A3KZC2TLRZLOA0  B000IEZE3G
# 3009  A2CQXJ7FPVJTYV  B000IEZE3G
# 3007            None  B000IEZE3G
# 3005   AYNKNXA92QMN1  B000IEZE3G
# ...              ...         ...
# 5600   AVAG7ND5A1NZB  B000IEZE3G
# 5599  A1HO9JF4W4JFX5  B000IEZE3G
# 5598  A14I2NQ6EYV5Y9  B000IEZE3G
# 5602  A2UZI75GS91BMX  B000IEZE3G
# 403   A1CCQ4QOXVHHQI  B000IEZE3G
#
#                                                title  \
# 3004    A magical read&#65533;in more ways than one!
# 3008     Anniversary Edition nice but not essential.
# 3009  Harry Potter and the Sorcerer's Stone (Book 1)
# 3007                                 Ages 9-12? Hah!
# 3005                       I want to go to Hogwarts!
# ...                                              ...
# 5600                           Where is my purchase?
# 5599                I'd be happier if it had arrived
# 5598                       Copyright infringment????
# 5602                                            LATE
# 403                                    not impressed
#
#                                                  review  rating  upvotes  \
# 3004  What a wonderful book! I read it after my 11-y...       5       45
# 3008  In today's economy, customers buying books nee...       5       45
# 3009  First of all, I am 52 years old. While I have ...       5       35
# 3007  Harry Potter and the Sorceror's Stone is one o...       5       58
# 3005  Granted, I lack the basic criterion for being ...       5       83
# ...                                                 ...     ...      ...
# 5600  My item was supposed to be delivered to my dor...       1        0
# 5599  This book has not arrived. I have written to t...       1        0
# 5598  This item was very unprofessional and I questi...       1        0
# 5602  I ordered this book about 25 days ago and it h...       1        0
# 403   I picked this book up (from my kids) because, ...       1        1
#
#       downvotes   timestamp    quality
# 3004          2   959040000  11.895324
# 3008          3  1221523200   9.499265
# 3009          2   950054400   9.372961
# 3007          5   943056000   8.637968
# 3005          8   949190400   8.546253
# ...         ...         ...        ...
# 5600         21  1242432000   0.094034
# 5599         21  1246406400   0.094034
# 5598         21  1249084800   0.094034
# 5602         22  1283040000   0.090110
# 403          36  1310342400   0.083221
#
# [6711 rows x 9 columns]

# %% [markdown]
# Notice how the unhelpful reviews in this case are all 1 star reviews. What happens when we remove the unhelpful reviews?

# %%
print(all_reviews.iloc[0].review.replace('.', '\n'))
# Out:
# What a wonderful book! I read it after my 11-year old son suggested it as a change from my usual reading fare of history and biography
#  It turned out to be much more than just a springtime reading diversion
#
#
# it became for me a &quot;magical&quot; reading experience in more ways than one
#  I was quickly captivated by Harry, Hagrid, Dumbledore, Hermoine, and yes, even the nasty Dursleys, Snape, and Draco Mafoy
#  Hogwarts came to life for me
#  I found myself unable to put the book down because it was so exciting and much fun to read! It's easy to understand why my son (and so many kids just like him) love Harry Potter so much
# J
# K
#  Rowling proves herself a gifted writer of children's books, not only because the plot is good and the characters come to life, but also because her writing fires the imagination and teaches positive values
# &quot;Harry Potter and the Sorcerer's Stone&quot; is a great book for kids of all ages
#
#
# from 9 to 99
#  It's destined to be a classic of children's literature

# %%
print("NOT HELPFUL:\n")
print(all_reviews.iloc[-1].review.replace('.', '\n'))
# Out:
# NOT HELPFUL:
#
# I picked this book up (from my kids) because, while reading reviews of the Twilight Saga, it was constantly being compared (unfairly, in my opinion) to HP
#  I have seen and LOVED all the HP movies, and consider myself an HP fan, but, this first book is a major disappointment
# I was expecting much better writing, more descriptive story telling and better characters
#  I am not finished with the book yet, and I will finish it, but I am not too sure I will finish the series
# To be fair, my 10 year old did tell me it was kinda boring, but he has read it 3 times
#
#
#  maybe I need to introduce him to the rest of my library! It has some fabulous fantasy in it
#  MUCH better than this
# This is the rare case where the movies are FAR superior to the books

# %%
print("Raw ratings:")
viz.plot_ratings(all_reviews.rating)
# Out:
# Raw ratings:

# %%
helpful_reviews = rev.sort_reviews(recommendations['reviews'])
helpful_reviews
# Out:
#              user_id  product_id  \
# 3004  A3IB1W0SVED0Z3  B000IEZE3G
# 4943  A1Y8894AO7LXLL  B000IEZE3G
# 4941  A21LH3VS24STZ9  B000IEZE3G
# 4942            None  B000IEZE3G
# 4940  A2G6VWD0GDY5PS  B000IEZE3G
# ...              ...         ...
# 5988            None  B000IEZE3G
# 5987  A1N6712C6JHYJ9  B000IEZE3G
# 1075  A1BG9FXFSSM3NK  B000IEZE3G
# 1076  A2XAWBF5J47ECS  B000IEZE3G
# 682    AIHJG9EQVVCS2  B000IEZE3G
#
#                                                   title  \
# 3004       A magical read&#65533;in more ways than one!
# 4943              Harry Potter and the Sorcerer's Stone
# 4941                            Harry Potter is for all
# 4942                                     A magical book
# 4940                        Can I Even Begin with them?
# ...                                                 ...
# 5988          I must be the only person in the world...
# 5987                 A Christian Review: I'm now a fan.
# 1075          This book, a bad book?...?... YEAH RIGHT!
# 1076                                            STUPID!
# 682   KINDLE VERSION: Pottermore a hassle...book is ...
#
#                                                  review  rating  upvotes  \
# 3004  What a wonderful book! I read it after my 11-y...       5       45
# 4943  Harry Potter and the Sorcerer's Stone by J.K. ...       5       12
# 4941  As a writer, I'm not ashamed to admit I have a...       5       12
# 4942  I heard so much about Book 4 in the series thr...       5       12
# 4940  When I first picked up this book it was the ch...       5       12
# ...                                                 ...     ...      ...
# 5988  I must be the only person in the world to not ...       2        4
# 5987  I must admit, with all the Christian hoopla su...       5        4
# 1075  Ok lets get this review started by saying that...       5        6
# 1076  The storyline is pretty good. I do like the id...       2        6
# 682   This is not a review about the Books.This is a...       1        9
#
#       downvotes   timestamp    quality
# 3004          2   959040000  14.694379
# 4943          0   949363200  11.690115
# 4941          0   966988800  11.690115
# 4942          0   964051200  11.690115
# 4940          0  1027036800  11.690115
# ...         ...         ...        ...
# 5988          4   915753600   1.163385
# 5987          4   996969600   1.163385
# 1075          6   991612800   1.118013
# 1076          6   972864000   1.118013
# 682           9  1341964800   1.083310
#
# [5984 rows x 9 columns]

# %%
print(f"Ratings with more helpful than unhelpful votes:")
viz.plot_ratings(helpful_reviews.rating)
# Out:
# Ratings with more helpful than unhelpful votes:

# %% [markdown]
# Interesting! Filtering unhelpful reviews substantially changes the distribution of ratings, all but eliminating the low end of the spectrum - all while removing about 10% of ratings.

# %% [markdown]
# ## Recommendations

# %%
book_recommendations = recommendations["recommendations"]
book_recommendations[:10]
# Out:
#             similarity                                              title  \
# B000N76ZCC    0.775787             Harry Potter & the Prisoner of Azkaban
# B000NPEWHE    0.729994            Harry Potter and the Chamber of Secrets
# B000GQG5MA    0.486340               The Hobbit; Or, There and Back Again
# B000Q032UY    0.484644                 The Hobbit or There and Back Again
# B000ILIJE0    0.484644                    The Hobbit There and Back Again
# B000NWU3I4    0.484644  The Hobbitt, or there and back again; illustra...
# B000NDSX6C    0.484644                                         The Hobbit
# B000NNOTXI    0.480117                             To Kill a Mocking Bird
# 0808510258    0.480117  Harper Lee's To Kill a Mockingbird (Barron's B...
# 0816156921    0.436613                 Dracula (G. K. Hall (Large Print))
#
#                                                       creator  \
# B000N76ZCC                                    Lisa S. Brenner
# B000NPEWHE                                      J. K. Rowling
# B000GQG5MA                                                nan
# B000Q032UY                                   J. R. R. Tolkien
# B000ILIJE0                          John Ronald Reuel Tolkien
# B000NWU3I4                                   J. R. R. Tolkien
# B000NDSX6C                                   J. R. R. Tolkien
# B000NNOTXI                                         Harper Lee
# 0808510258                           Joyce Milton, Harper Lee
# 0816156921  Bram Stoker, Grand Theatre Collection (Univers...
#
#                             publisher  \
# B000N76ZCC                  McFarland
# B000NPEWHE            Raincoast Books
# B000GQG5MA                       None
# B000Q032UY              Mariner Books
# B000ILIJE0                       None
# B000NWU3I4  Houghton Mifflin Harcourt
# B000NDSX6C              Mariner Books
# B000NNOTXI        Dramatic Publishing
# 0808510258           Turtleback Books
# 0816156921                       None
#
#                                                   description category  \
# B000N76ZCC  Through classroom activities, wizard rock conc...    Books
# B000NPEWHE                    Witchcraft, wizardry - fiction.    Books
# B000GQG5MA                                               None    Books
# B000Q032UY  Celebrating 75 years of one of the world's mos...    Books
# B000ILIJE0  The adventures of the well-to-do hobbit, Bilbo...    Books
# B000NWU3I4  Bilbo Baggins, a respectable, well-to-do hobbi...    Books
# B000NDSX6C  Celebrating 75 years of one of the world's mos...    Books
# B000NNOTXI  Harper Lee's classic novel of a lawyer in the ...    Books
# 0808510258  A guide to reading "To Kill A Mockingbird" wit...    Books
# 0816156921  Having deduced the double identity of Count Dr...    Books
#
#                                    subcategory release_date
# B000N76ZCC                  Literary Criticism   2015-06-11
# B000NPEWHE                    Juvenile Fiction         1999
# B000GQG5MA                                 nan         None
# B000Q032UY                    Juvenile Fiction         2012
# B000ILIJE0                   Adventure stories         1966
# B000NWU3I4                             Fiction         2013
# B000NDSX6C                    Juvenile Fiction         2012
# B000NNOTXI                               Drama         1970
# 0808510258                 Juvenile Nonfiction   1984-10-01
# 0816156921  High interest-low vocabulary books         199?

# %% [markdown]
# ## Filtering
#
# Unfiltered recommendations took over 10sec in this case and resulted in products with universally low similarity scores, leading to the development of filters.
#
# This case is a good example for exploring how filtering reviewers and/or products affects performance and recommendations:

# %% [markdown]
# ### Raw Recommendations
# Let's remove all the filters and see a recommendation based on the full set of reviews related to this product:

# %%
raw_recommendations = q.get_recommendations(
    category = category, search_term = search_term, search_field = field, exact_match = exact_match,
    conn = conn, 
    filter_unhelpful_reviews = False, reviewer_max_pool_size = None
)
raw_recommendations['recommendations']
# Out:
# find_products: 1 results in 0.016 seconds
# 0.0164: Found 1 products
# SELECT * FROM review WHERE product_id IN (?)
# ['B000IEZE3G']
# 0.0314: Got 6711 reviews
# 0.157: Got 49380 related reviews of 21570 products by 3663 users
# 0.171: Filtered 19852 related reviews by user and/or product
# 0.184: Created ratings table for 1000 products by 3663 users
# 0.223: Calculated similarities
# 0.335: Removed 86 duplicate editions of the same product
# 0.336: Added product details
#             similarity                                              title  \
# B000NPEWHE    0.410490            Harry Potter and the Chamber of Secrets
# B000N76ZCC    0.346244             Harry Potter & the Prisoner of Azkaban
# B000Q032UY    0.156430                 The Hobbit or There and Back Again
# B000ILIJE0    0.156430                    The Hobbit There and Back Again
# B000NWU3I4    0.155261  The Hobbitt, or there and back again; illustra...
# ...                ...                                                ...
# 034073891X    0.081258                                 Hearts in Atlantis
# B000HM6M30    0.080878            The Drawing of the 3: The Dark Tower II
# 0753110296    0.080336                         Interview with the Vampire
# B000PVY3FW    0.080336    Interview With The Vampire SIGNED First Edition
# 9626341823    0.080292                A Christmas Carol (Classic Fiction)
#
#                               creator                        publisher  \
# B000NPEWHE              J. K. Rowling                  Raincoast Books
# B000N76ZCC            Lisa S. Brenner                        McFarland
# B000Q032UY           J. R. R. Tolkien                    Mariner Books
# B000ILIJE0  John Ronald Reuel Tolkien                             None
# B000NWU3I4           J. R. R. Tolkien        Houghton Mifflin Harcourt
# ...                               ...                              ...
# 034073891X               Stephen King               Simon and Schuster
# B000HM6M30               Stephen King  Donald m Grant Pub Incorporated
# 0753110296                  Anne Rice       Random House Digital, Inc.
# B000PVY3FW                  Anne Rice                      Hachette UK
# 9626341823                        nan                             None
#
#                                                   description category  \
# B000NPEWHE                    Witchcraft, wizardry - fiction.    Books
# B000N76ZCC  Through classroom activities, wizard rock conc...    Books
# B000Q032UY  Celebrating 75 years of one of the world's mos...    Books
# B000ILIJE0  The adventures of the well-to-do hobbit, Bilbo...    Books
# B000NWU3I4  Bilbo Baggins, a respectable, well-to-do hobbi...    Books
# ...                                                       ...      ...
# 034073891X  King mesmerizes readers with fiction deeply ro...    Books
# B000HM6M30  After his confrontation with the man in black ...    Books
# 0753110296  Recounting his first two hundred years of life...    Books
# B000PVY3FW  From #1 New York Times bestselling author Anne...    Books
# 9626341823                                               None    Books
#
#                    subcategory release_date
# B000NPEWHE    Juvenile Fiction         1999
# B000N76ZCC  Literary Criticism   2015-06-11
# B000Q032UY    Juvenile Fiction         2012
# B000ILIJE0   Adventure stories         1966
# B000NWU3I4             Fiction         2013
# ...                        ...          ...
# 034073891X             Fiction   2017-11-14
# B000HM6M30             Fiction         1987
# 0753110296             Fiction         1977
# B000PVY3FW             Fiction   2015-01-29
# 9626341823                 nan         None
#
# [100 rows x 8 columns]

# %% [markdown]
# ## Filter sparse users or products

# %%
# Experimentation has shown that filtering by users with many reviews (not by products with many reviews)
# produces the highest similarity scores and seemingly sensible recommendations.
user_count_cutoff = None
product_count_cutoff = 100

ratings_by_user = related_reviews.groupby('user_id')['rating'].count().sort_values(ascending = False)
ratings_by_user
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 6
#       3 user_count_cutoff = None
#       4 product_count_cutoff = 100
# ----> 6 ratings_by_user = related_reviews.groupby('user_id')['rating'].count().sort_values(ascending = False)
#       7 ratings_by_user
#
# NameError: name 'related_reviews' is not defined

# %%
ratings_by_user.value_counts(normalize=True).cumsum()[:20]
# Out:
# rating
# 1     0.394464
# 2     0.483276
# 3     0.545559
# 4     0.584775
# 5     0.614764
# 6     0.638985
# 7     0.659746
# 10    0.677047
# 13    0.692042
# 11    0.707036
# 9     0.720877
# 12    0.734717
# 20    0.743945
# 18    0.753172
# 8     0.762399
# 14    0.770473
# 17    0.778547
# 21    0.786621
# 53    0.794694
# 28    0.801615
# Name: proportion, dtype: float64

# %%
ratings_by_product = related_reviews.groupby('product_id')['rating'].count().sort_values(ascending = False)
ratings_by_product
# Out:
# product_id
# B000IEZE3G    867
# B000NPEWHE    202
# B000N76ZCC    144
# B000Q032UY     46
# B000ILIJE0     46
#              ...
# 0940242141      1
# 0940242303      1
# 0941678423      1
# 0942235304      1
# B005MX54HO      1
# Name: rating, Length: 11007, dtype: int64

# %%
ratings_by_product.value_counts(normalize=True).cumsum()[:20]
# Out:
# rating
# 1     0.736350
# 2     0.863451
# 3     0.913510
# 4     0.937403
# 5     0.950577
# 6     0.959844
# 8     0.967657
# 7     0.974743
# 9     0.980921
# 10    0.985100
# 11    0.987553
# 12    0.990006
# 16    0.992187
# 13    0.993913
# 20    0.995639
# 14    0.996729
# 19    0.997456
# 27    0.998183
# 18    0.998728
# 15    0.999001
# Name: proportion, dtype: float64

# %%
def filter_reviews(reviews: pd.DataFrame, user_cutoff = None, product_cutoff = None) -> pd.DataFrame:
    result = reviews.copy()
    if user_count_cutoff != None:
        ratings_by_user = related_reviews.groupby('user_id')['rating'].count().sort_values(ascending = False)
        users = ratings_by_user[:user_count_cutoff]
        result = result[related_reviews.user_id.isin(users.index)]

    if product_count_cutoff != None:
        ratings_by_product = related_reviews.groupby('product_id')['rating'].count().sort_values(ascending = False)
        products = ratings_by_product[:product_count_cutoff]
        result = result[related_reviews.product_id.isin(products.index)]
    return result

related_reviews_filtered = filter_reviews(related_reviews, user_count_cutoff, product_count_cutoff)
related_reviews_filtered
# Out:
#               user_id  product_id  \
# 1      A1058D8UFZL711  B000IEZE3G
# 2      A10A8EMU0FLK49  B000IEZE3G
# 3      A10EH95EUDO9W3  0060765461
# 31     A10EH95EUDO9W3  B00005W9DZ
# 41     A10EH95EUDO9W3  B000G1JYHI
# ...               ...         ...
# 21052   AZXQKAMHK35PA  1850891648
# 21058   AZXQKAMHK35PA  B000F5X89K
# 21060   AZXQKAMHK35PA  B000GLJG76
# 21062   AZXQKAMHK35PA  B000IEZE3G
# 21066   AZYQ50LOMUJB7  B000IEZE3G
#
#                                                   title  \
# 1                                      About the Series
# 2                              This mom loved the books
# 3         Once a child's book, now a classic literature
# 31        Once a child's book, now a classic literature
# 41        Once a child's book, now a classic literature
# ...                                                 ...
# 21052               Different and Better than Expected.
# 21058               Different and Better than Expected.
# 21060                                         Wonderful
# 21062  Great - got me (an adult) to start reading again
# 21066                                        Great Read
#
#                                                   review  rating  upvotes  \
# 1      It is really difficult to speak to everyone's ...       5        1
# 2      I bought all three Harry Potter books for my 1...       5        4
# 3      When I was in junior high school, my teacher i...       4        0
# 31     When I was in junior high school, my teacher i...       4        0
# 41     When I was in junior high school, my teacher i...       4        0
# ...                                                  ...     ...      ...
# 21052  I have seen so many Frankenstein movies. As a ...       5        0
# 21058  I have seen so many Frankenstein movies. As a ...       5        0
# 21060  This book was wonderful. It is a story of work...       5        2
# 21062  When I picked up this book to read a couple of...       5        3
# 21066  I've been hesitant for YEARS to read this nove...       4        1
#
#        downvotes   timestamp
# 1              0  1185926400
# 2              0   943747200
# 3              0   956016000
# 31             0   956016000
# 41             0   956016000
# ...          ...         ...
# 21052          0  1119225600
# 21058          0  1119225600
# 21060          1  1117756800
# 21062          0  1120780800
# 21066          0  1030752000
#
# [3065 rows x 8 columns]

# %%
recommendations = q.get_recommendations_from_reviews(product.id, related_reviews_filtered, conn)
recommendations[:20]
# Out:
# 0.00257: Created pivot table of ratings for 100 products by 867 users
# 0.00339: Created sparse matrix
# 0.00384: Calculated similarities
# 0.00531: Added product details
#             similarity                                              title  \
# B000NPEWHE    0.482089            Harry Potter and the Chamber of Secrets
# B000N76ZCC    0.401933             Harry Potter & the Prisoner of Azkaban
# B000Q032UY    0.220454                 The Hobbit or There and Back Again
# B000ILIJE0    0.220454                    The Hobbit There and Back Again
# B000GQG5MA    0.220085               The Hobbit; Or, There and Back Again
# B000NDSX6C    0.217727                                         The Hobbit
# B000NWU3I4    0.217008  The Hobbitt, or there and back again; illustra...
# B000JJVHZE    0.175797                              To Kill A Mockingbird
# B000K7WNQW    0.175797                              To Kill a Mockingbird
# B0007DRGI4    0.175797                              To kill a mockingbird
# B000NNOTXI    0.175797                             To Kill a Mocking Bird
# 0808510258    0.175797  Harper Lee's To Kill a Mockingbird (Barron's B...
# B000PCESRE    0.158633                             The Catcher in the Rye
# B000PMCF1A    0.158633  The Catcher in the Rye [Audiobook] [Cd] [Unabr...
# B000I3NFKG    0.157709                             THE CATCHER IN THE RYE
# 0816156921    0.150542                 Dracula (G. K. Hall (Large Print))
# 1556909330    0.149034                                               Dune
# 8188280046    0.146937                Pride & Prejudice (Classic Library)
# 1844560333    0.146937                                Pride and Prejudice
# 0435126075    0.146937                   Pride & Prejudice (New Windmill)
#
#                                             title_search  \
# B000NPEWHE                harrypotterandchamberofsecrets
# B000N76ZCC                  harrypotterprisonerofazkaban
# B000Q032UY                        hobbitorreandbackagain
# B000ILIJE0                          hobbitreandbackagain
# B000GQG5MA                        reandbackagainhobbitor
# B000NDSX6C                                        hobbit
# B000NWU3I4    orreandbackagainillustratedbyauthorhobbitt
# B000JJVHZE                            tokillamockingbird
# B000K7WNQW                            tokillamockingbird
# B0007DRGI4                            tokillamockingbird
# B000NNOTXI                            tokillamockingbird
# 0808510258  harperleestokillamockingbirdbarronsbooknotes
# B000PCESRE                                  catcherinrye
# B000PMCF1A      catcherinryeaudiobookcdunabridgedaudiocd
# B000I3NFKG                                  catcherinrye
# 0816156921                       draculagkhalllargeprint
# 1556909330                                          dune
# 8188280046                  prideprejudiceclassiclibrary
# 1844560333                             prideandprejudice
# 0435126075                     prideprejudicenewwindmill
#
#                                                       creator  \
# B000NPEWHE                                      J. K. Rowling
# B000N76ZCC                                    Lisa S. Brenner
# B000Q032UY                                   J. R. R. Tolkien
# B000ILIJE0                          John Ronald Reuel Tolkien
# B000GQG5MA                                                nan
# B000NDSX6C                                   J. R. R. Tolkien
# B000NWU3I4                                   J. R. R. Tolkien
# B000JJVHZE                                         Harper Lee
# B000K7WNQW                                         Harper Lee
# B0007DRGI4                                         Harper Lee
# B000NNOTXI                                         Harper Lee
# 0808510258                           Joyce Milton, Harper Lee
# B000PCESRE                                                nan
# B000PMCF1A                                       John Donovan
# B000I3NFKG                                      J.D. Salinger
# 0816156921  Bram Stoker, Grand Theatre Collection (Univers...
# 1556909330                                     Tanya Lapointe
# 8188280046                                          Ibi Zoboi
# 1844560333                                        Jane Austen
# 0435126075                                          Ibi Zoboi
#
#                                                creator_search  \
# B000NPEWHE                                          jkrowling
# B000N76ZCC                                       lisasbrenner
# B000Q032UY                                         jrrtolkien
# B000ILIJE0                             johnronaldreueltolkien
# B000GQG5MA                                                nan
# B000NDSX6C                                         jrrtolkien
# B000NWU3I4                                         jrrtolkien
# B000JJVHZE                                          harperlee
# B000K7WNQW                                          harperlee
# B0007DRGI4                                          harperlee
# B000NNOTXI                                          harperlee
# 0808510258                               harperleejoycemilton
# B000PCESRE                                                nan
# B000PMCF1A                                        johndonovan
# B000I3NFKG                                         jdsalinger
# 0816156921  bramstokergrandatrecollectionuniversityofguelp...
# 1556909330                                      tanyalapointe
# 8188280046                                           ibizoboi
# 1844560333                                         janeausten
# 0435126075                                           ibizoboi
#
#                             publisher  \
# B000NPEWHE            Raincoast Books
# B000N76ZCC                  McFarland
# B000Q032UY              Mariner Books
# B000ILIJE0                       None
# B000GQG5MA                       None
# B000NDSX6C              Mariner Books
# B000NWU3I4  Houghton Mifflin Harcourt
# B000JJVHZE             Harper Collins
# B000K7WNQW        Dramatic Publishing
# B0007DRGI4             Harper Collins
# B000NNOTXI        Dramatic Publishing
# 0808510258           Turtleback Books
# B000PCESRE                       None
# B000PMCF1A  North Star Editions, Inc.
# B000I3NFKG              Little, Brown
# 0816156921                       None
# 1556909330         Simon and Schuster
# 8188280046              HarperCollins
# 1844560333        Courier Corporation
# 0435126075              HarperCollins
#
#                                                   description category  \
# B000NPEWHE                    Witchcraft, wizardry - fiction.    Books
# B000N76ZCC  Through classroom activities, wizard rock conc...    Books
# B000Q032UY  Celebrating 75 years of one of the world's mos...    Books
# B000ILIJE0  The adventures of the well-to-do hobbit, Bilbo...    Books
# B000GQG5MA                                               None    Books
# B000NDSX6C  Celebrating 75 years of one of the world's mos...    Books
# B000NWU3I4  Bilbo Baggins, a respectable, well-to-do hobbi...    Books
# B000JJVHZE  Voted America's Best-Loved Novel in PBS's The ...    Books
# B000K7WNQW  Harper Lee's classic novel of a lawyer in the ...    Books
# B0007DRGI4  Voted America's Best-Loved Novel in PBS's The ...    Books
# B000NNOTXI  Harper Lee's classic novel of a lawyer in the ...    Books
# 0808510258  A guide to reading "To Kill A Mockingbird" wit...    Books
# B000PCESRE                                               None    Books
# B000PMCF1A  I’ll Get There. It Better Be Worth the Trip. i...    Books
# B000I3NFKG  Anyone who has read J. D. Salinger's New Yorke...    Books
# 0816156921  Having deduced the double identity of Count Dr...    Books
# 1556909330  Immerse yourself in the world of Denis Villene...    Books
# 8188280046  In a timely update of Jane Austen's Pride and ...    Books
# 1844560333  In early nineteenth-century England, a spirite...    Books
# 0435126075  In a timely update of Jane Austen's Pride and ...    Books
#
#                                    subcategory release_date
# B000NPEWHE                    Juvenile Fiction         1999
# B000N76ZCC                  Literary Criticism   2015-06-11
# B000Q032UY                    Juvenile Fiction         2012
# B000ILIJE0                   Adventure stories         1966
# B000GQG5MA                                 nan         None
# B000NDSX6C                    Juvenile Fiction         2012
# B000NWU3I4                             Fiction         2013
# B000JJVHZE                             Fiction   2014-07-08
# B000K7WNQW                               Drama         1970
# B0007DRGI4                             Fiction   2014-07-08
# B000NNOTXI                               Drama         1970
# 0808510258                 Juvenile Nonfiction   1984-10-01
# B000PCESRE                                 nan         None
# B000PMCF1A                 Young Adult Fiction   2010-09-08
# B000I3NFKG                             Fiction   1951-07-16
# 0816156921  High interest-low vocabulary books         199?
# 1556909330                                 Art   2021-10-22
# 8188280046                 Young Adult Fiction   2018-09-18
# 1844560333                             Fiction   1995-01-01
# 0435126075                 Young Adult Fiction   2018-09-18
